# %% [markdown]
# ## Pattern 1

# %%
for i in range(1,6):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ## Pattern 2

# %%
for i in range(5,0,-1):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *
